# %%
import boto3

client = boto3.client('dynamodb')
paginator = client.get_paginator('scan')

pages = []
for page in paginator.paginate(TableName='Loc'):
    pages.append(page)
print(pages)
# Out:
# [{'Items': [{'location': {'S': 'Av. America, Esquina Insurgentes, Mexico DF'}, 'plate': {'S': '998PLU'}, 'cameraAddres': {'M': {'lat': {'S': '-17.956969'}, 'lon': {'S': '-67.109257'}}}, 'status': {'S': 'NONE'}, 'image_path': {'S': 'https://s3.amazonaws.com/raw-assets-dems/17-15-59_ROJO_directo_x1_-Infraccion_4129FFR_100/2018-02-21_17-15-59_0wm_croped_detected.jpg'}, 'uID': {'S': '59165434276'}, 'datetime': {'S': '2018-02-21'}, 'infraccionID': {'S': '24eb2f0c-0e8d-4f42-9bdb-28b14e698214'}, 'token': {'S': 'ck5V54ms06M:APA91bExvKLgKcMKSz24b8AqXhjkne8H-putU32KdcJqFL5I6j4V0hKxLHOx70qR6te9SvMd_dKpIVJtNsnZqmbhDXZ_uQaMdjF8wv7_Sl-zfE7qkSpUz-x4w-S_oj67wdmTcmvlbyyAZfvzEmlpdIM52vYyxDXjtA'}, 'prob': {'S': '0.94'}, 'hour': {'S': '17:15:59'}, 'video_path': {'S': 'https://s3.amazonaws.com/raw-assets-dems/17-15-59_ROJO_directo_x1_-Infraccion_4129FFR_100/2018-02-21_17-15-59_video_.mp4'}, 'firebaseid': {'S': 'VGG2kNf0ljeprKh5whUgpvo2IG42'}}, {'location': {'S': 'debug'}, 'plate': {'S': 'G84ATA'}, 'camer
# ...

# %%
len(pages[0]['Items'])
# Out:
# 268
